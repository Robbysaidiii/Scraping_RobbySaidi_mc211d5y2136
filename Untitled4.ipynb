# %% [markdown]
# <a href="https://colab.research.google.com/github/Robbysaidiii/Scraping_RobbySaidi_mc211d5y2136/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah-langkah penyelesaian melitputi:
#
# 1.  Data Acquisition
# 2.  Exploratory Data Analysis (EDA)
# 3.  Pre-processing
# - Case Folding
# - Filtering
# - Stopword
# - Stemming
# 4.  Feature Engineering
# - Feature Extraction - TF IDF
# - Feature Selection - Chi-Square
# 5. Modelling (Machine Learning)
# 6. Prediction
# 7. Model Evaluation
# 8. inference

# %% [markdown]
# # Modules dan Packages

# %%
# !pip -q install sastrawi
# !pip -q install nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pickle

import re
import nltk
nltk.download('stopwords')

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

import random
from joblib import dump

from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Data Acquisition
# Penjelasan Label
#
# - 0: positif
#
# - 1: negatif
#
# - 2: netral

# %%
from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/Dataset hasil scraping dengan ulasan_aplikasi_twitter.csv')

data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#           userName  Rating                                             Review  \
# 0  Pengguna Google       2  Banyak bug, jadi lemot (foto atau video sering...
# 1  Pengguna Google       1  Saya baru instal lagi x ini, mau login eh "mem...
# 2  Pengguna Google       1  semenjak jadi X malah lemot, minta update seri...
# 3  Pengguna Google       4  Kok banyak video permasalahan dan lemot padaha...
# 4  Pengguna Google       5  Untuk pihak X, mohon tambahkan fitur "juga bis...
#
#                Tanggal
# 0  2025-03-11 15:06:40
# 1  2025-03-10 14:18:48
# 2  2025-02-04 22:06:28
# 3  2025-01-15 13:22:01
# 4  2025-03-04 18:53:12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11111 entries, 0 to 11110
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   userName  11111 non-null  object
#  1   Rating    11111 non-null  int64
#  2   Review    11111 non-null  object
#  3   Tanggal   11111 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 347.3+ KB

# %%
print('Total Jumlah Review:', data.shape[0], 'data\n')
print('Terdiri dari (berdasarkan rating):')
print('-- [Negatif] Rating 1-2\t:', data[data['Rating'] <= 2].shape[0], 'data')
print('-- [Netral] Rating 3\t:', data[data['Rating'] == 3].shape[0], 'data')
print('-- [Positif] Rating 4-5\t:', data[data['Rating'] >= 4].shape[0], 'data\n')
# Out:
# Total Jumlah Review: 11111 data
#
# Terdiri dari (berdasarkan rating):
# -- [Negatif] Rating 1-2	: 8025 data
# -- [Netral] Rating 3	: 1062 data
# -- [Positif] Rating 4-5	: 2024 data

# %%
height = data['Rating'].value_counts().sort_index()
labels = height.index.astype(str)  # ['1', '2', ..., '5']
y_pos  = np.arange(len(labels))

plt.figure(figsize=(7,4), dpi=80)
plt.ylim(0, max(height) + 10)
plt.title('Distribusi Rating Review', fontweight='bold')
plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Jumlah', fontweight='bold')
plt.bar(y_pos, height, color='skyblue')
plt.xticks(y_pos, labels)
plt.show()

# %% [markdown]
# #Text Preprocessing

# %% [markdown]
# ##Case Folding

# %%
import re

def casefolding(text):
    text = text.lower()                               # Mengubah ke huruf kecil
    text = re.sub(r'https?://\S+|www\.\S+', '', text) # Menghapus URL
    text = re.sub(r'[-+]?[0-9]+', '', text)           # Menghapus angka
    text = re.sub(r'[^\w\s]', '', text)               # Menghapus tanda baca
    text = text.strip()
    return text

# %%
raw_sample   = data['Review'].iloc[0]
case_folding = casefolding(raw_sample)

print('Raw data\t: ', raw_sample)
print('Case folding\t: ', case_folding)
# Out:
# Raw data	:  Banyak bug, jadi lemot (foto atau video sering nggak muncul/nggak keputer) padahal wifi lancar. Ganti kuota juga lancar pdhl. Sering ke refresh sendiri padahal lagi asik baca timeline. Intinya udah nggak kaya dulu dah
# Case folding	:  banyak bug jadi lemot foto atau video sering nggak munculnggak keputer padahal wifi lancar ganti kuota juga lancar pdhl sering ke refresh sendiri padahal lagi asik baca timeline intinya udah nggak kaya dulu dah

# %% [markdown]
# ##Word Normalization

# %%
key_norm = pd.read_csv('/content/drive/MyDrive/Dataset hasil scraping dengan ulasan_aplikasi_twitter.csv')
# Print the columns of key_norm to verify if 'singkat' and 'hasil' columns exist
print(key_norm.columns)

def text_normalize(text):
  # Replace 'singkat' and 'hasil' with the actual column names if they are different
  # For example, if the columns are named 'abbreviation' and 'full_form', use those instead.
  text = ' '.join([key_norm[key_norm['singkat'] == word]['hasil'].values[0] if (key_norm['singkat'] == word).any() else word for word in text.split()])
  text = str.lower(text)
  return text
# Out:
# Index(['userName', 'Rating', 'Review', 'Tanggal'], dtype='object')

# %% [markdown]
# ##Filtering (Stopword Removal)

# %%
stopwords_ind = stopwords.words('indonesian')

# %%
len(stopwords_ind)
# Out:
# 758

# %%
stopwords_ind
# Out:
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
# ...

# %%
#Buat fungsi untuk langkah stopword removal

more_stopword = ['tsel', 'gb', 'rb']                    # Tambahkan kata dalam daftar stopword
stopwords_ind = stopwords_ind + more_stopword

def remove_stop_words(text):
  clean_words = []
  text = text.split()
  for word in text:
      if word not in stopwords_ind:
          clean_words.append(word)
  return " ".join(clean_words)

# %%
raw_sample       = data['Review'].iloc[0]
case_folding     = casefolding(raw_sample)
stopword_removal = remove_stop_words(case_folding)

print('Raw data\t\t: ', raw_sample)
print('Case folding\t\t: ', case_folding)
print('Stopword removal\t: ', stopword_removal)
# Out:
# Raw data		:  Banyak bug, jadi lemot (foto atau video sering nggak muncul/nggak keputer) padahal wifi lancar. Ganti kuota juga lancar pdhl. Sering ke refresh sendiri padahal lagi asik baca timeline. Intinya udah nggak kaya dulu dah
# Case folding		:  banyak bug jadi lemot foto atau video sering nggak munculnggak keputer padahal wifi lancar ganti kuota juga lancar pdhl sering ke refresh sendiri padahal lagi asik baca timeline intinya udah nggak kaya dulu dah
# Stopword removal	:  bug lemot foto video nggak munculnggak keputer wifi lancar ganti kuota lancar pdhl refresh asik baca timeline intinya udah nggak kaya dah

# %% [markdown]
# ##Stemming

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Buat fungsi untuk langkah stemming bahasa Indonesia
def stemming(text):
  text = stemmer.stem(text)
  return text

# %%
raw_sample       = data['Review'].iloc[5]
case_folding     = casefolding(raw_sample)
stopword_removal = remove_stop_words(case_folding)
text_stemming    = stemming(stopword_removal)

print('Raw data\t\t: ', raw_sample)
print('Case folding\t\t: ', case_folding)
print('Stopword removal\t: ', stopword_removal)
print('Stemming\t\t: ', text_stemming)
# Out:
# Raw data		:  Pihak "X" tolong ini bug atau emang gitu, di perbaiki Padahal dulu bisa lihat semua postingan sampe habis, tapi kenapa sekarang gak bisa lihat postingan foto sampai habis, mohon di perbaiki🙏 Dan juga sering refres ngulang dari awal pas lihat-lihat postingan Mohon di perbaiki jika itu memang bug🙏
# Case folding		:  pihak x tolong ini bug atau emang gitu di perbaiki padahal dulu bisa lihat semua postingan sampe habis tapi kenapa sekarang gak bisa lihat postingan foto sampai habis mohon di perbaiki dan juga sering refres ngulang dari awal pas lihatlihat postingan mohon di perbaiki jika itu memang bug
# Stopword removal	:  x tolong bug emang gitu perbaiki lihat postingan sampe habis gak lihat postingan foto habis mohon perbaiki refres ngulang pas lihatlihat postingan mohon perbaiki bug
# Stemming		:  x tolong bug emang gitu baik lihat postingan sampe habis gak lihat postingan foto habis mohon baik refres ngulang pas lihatlihat postingan mohon baik bug

# %% [markdown]
# ##Text Preprocessing Pipeline

# %%
# Buat fungsi untuk menggabungkan seluruh langkah text preprocessing
def text_preprocessing_process(text):
  text = casefolding(text)
  text = text_normalize(text)
  text = remove_stop_words(text)
  text = stemming(text)
  return text

# %%
# %%time
data['clean_teks'] = data['Review'].apply(text_preprocessing_process)

# Perhatikan waktu komputasi ketika proses text preprocessing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'singkat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# ...

# %%
print(data.columns)  # Cek kolom yang ada dalam DataFrame 'data'
# Out:
# Index(['userName', 'Rating', 'Review', 'Tanggal'], dtype='object')
